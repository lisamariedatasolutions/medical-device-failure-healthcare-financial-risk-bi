# %%
# Source Log

| Item | Source |
|---|---|
| Primary dataset platform | Kaggle |
| Primary dataset name | Medical Device Failure Dataset – Anonymized |
| Primary dataset author | antoinepierreno |
| Primary file name | Medical_Device_Failure_dataset.csv |
| Primary dataset rows | 4,149 |
| Primary dataset columns | 13 |
| Primary project role | Main medical device failure and maintenance dataset |
| Secondary file name | financial_data.csv |
| Secondary dataset rows | 500 |
| Secondary dataset columns | 4 |
| Secondary project role | Financial support dataset used to analyze healthcare operating expenses related to equipment, supplies, and staffing |
| Removed dataset | supply_chain_data.csv |
| Reason removed | The previous supply chain dataset contained non-healthcare product categories such as haircare, skincare, and cosmetics, so it did not fit the healthcare operations theme |
| Notes | The final project focuses on medical device failure, maintenance burden, downtime, and financial impact in a healthcare operations context. |
